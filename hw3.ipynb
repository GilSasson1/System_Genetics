# %% [markdown]
# # Assignment 3 in System Genetics - Gil Sasson & Tomer Schweid

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import GEOparse
from sklearn.feature_selection import f_regression
from statsmodels.stats.multitest import fdrcorrection
from itertools import chain
from collections import Counter

# %% [markdown]
# # Part A: eQTL analysis

# %% [markdown]
# ## Preprocessing

# %%
directory_path = "/Users/gilsasson/PycharmProjects/pythonProject/System_Genetics/data/"

# %%
# Download the alphabet
gse_myeloid = GEOparse.get_GEO(geo='GSE18067', destdir=directory_path)
gse_liver = GEOparse.get_GEO(geo='GSE17522', destdir=directory_path)
# Out:
# 20-Sep-2024 17:41:27 DEBUG utils - Directory /Users/gilsasson/PycharmProjects/pythonProject/System_Genetics/data/ already exists. Skipping.
# 20-Sep-2024 17:41:27 INFO GEOparse - File already exist: using local version.
# 20-Sep-2024 17:41:27 INFO GEOparse - Parsing /Users/gilsasson/PycharmProjects/pythonProject/System_Genetics/data/GSE18067_family.soft.gz:
# 20-Sep-2024 17:41:27 DEBUG GEOparse - DATABASE: GeoMiame
# 20-Sep-2024 17:41:27 DEBUG GEOparse - SERIES: GSE18067
# 20-Sep-2024 17:41:27 DEBUG GEOparse - PLATFORM: GPL6238
# 20-Sep-2024 17:41:27 DEBUG GEOparse - SAMPLE: GSM451699
# 20-Sep-2024 17:41:27 DEBUG GEOparse - SAMPLE: GSM451700
# 20-Sep-2024 17:41:27 DEBUG GEOparse - SAMPLE: GSM451701
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451702
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451703
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451704
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451705
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451706
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451707
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451708
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451709
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451710
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451711
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451712
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451713
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451714
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451715
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451716
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451717
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451718
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451719
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451720
# 20-Sep-2024 17:41:28 DEBUG GEOparse - SAMPLE: GSM451721
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451722
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451723
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451724
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451725
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451726
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451727
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451728
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451729
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451730
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451731
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451732
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451733
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451734
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451735
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451736
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451737
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451738
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451739
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451740
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451741
# 20-Sep-2024 17:41:29 DEBUG GEOparse - SAMPLE: GSM451742
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451743
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451744
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451745
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451746
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451747
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451748
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451749
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451750
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451751
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451752
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451753
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451754
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451755
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451756
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451757
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451758
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451759
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451760
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451761
# 20-Sep-2024 17:41:30 DEBUG GEOparse - SAMPLE: GSM451762
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451763
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451764
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451765
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451766
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451767
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451768
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451769
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451770
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451771
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451772
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451773
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451774
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451775
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451776
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451777
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451778
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451779
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451780
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451781
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451782
# 20-Sep-2024 17:41:31 DEBUG GEOparse - SAMPLE: GSM451783
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451784
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451785
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451786
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451787
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451788
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451789
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451790
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451791
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451792
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451793
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451794
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451795
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451796
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451797
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM451798
# 20-Sep-2024 17:41:32 DEBUG utils - Directory /Users/gilsasson/PycharmProjects/pythonProject/System_Genetics/data/ already exists. Skipping.
# 20-Sep-2024 17:41:32 INFO GEOparse - File already exist: using local version.
# 20-Sep-2024 17:41:32 INFO GEOparse - Parsing /Users/gilsasson/PycharmProjects/pythonProject/System_Genetics/data/GSE17522_family.soft.gz:
# 20-Sep-2024 17:41:32 DEBUG GEOparse - DATABASE: GeoMiame
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SERIES: GSE17522
# 20-Sep-2024 17:41:32 DEBUG GEOparse - PLATFORM: GPL6466
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM436705
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM436706
# 20-Sep-2024 17:41:32 DEBUG GEOparse - SAMPLE: GSM436707
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436708
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436709
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436710
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436711
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436712
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436713
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436714
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436715
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436716
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436717
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436718
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436719
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436720
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436721
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436722
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436723
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436724
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436725
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436726
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436727
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436728
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436729
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436730
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436731
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436732
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436733
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436734
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436735
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436736
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436737
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436738
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436739
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436740
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436741
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436742
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436743
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436744
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436745
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436746
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436747
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436748
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436749
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436750
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436751
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436752
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436753
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436754
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436755
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436756
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436757
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436758
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436759
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436760
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436761
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436762
# 20-Sep-2024 17:41:33 DEBUG GEOparse - SAMPLE: GSM436763
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436764
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436765
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436766
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436767
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436768
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436769
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436770
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436771
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436772
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436773
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436774
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436775
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436776
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436777
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436778
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436779
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436780
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436781
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436782
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436783
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436784
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436785
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436786
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436787
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436788
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436789
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436790
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436791
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436792
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436793
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436794
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436795
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436796
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436797
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436798
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436799
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436800
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436801
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436802
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436803
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436804
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436805
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436806
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436807
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436808
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436809
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436810
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436811
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436812
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436813
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436814
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436815
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436816
# 20-Sep-2024 17:41:34 DEBUG GEOparse - SAMPLE: GSM436817
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436818
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436819
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436820
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436821
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436822
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436823
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436824
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436825
# 20-Sep-2024 17:41:35 DEBUG GEOparse - SAMPLE: GSM436826

# %%
# Get the myeloid metadata
metadata_myeloid = pd.read_csv(directory_path + "metadata myeloid.txt", sep="\t")
metadata_myeloid.head()
# Out:
#     GSM name                  Strain
# 0  GSM451699    BXD13 Myeloid batch1
# 1  GSM451700  BXD23 Erythroid batch1
# 2  GSM451701  BXD40 Erythroid batch1
# 3  GSM451702    BXD36 Myeloid batch1
# 4  GSM451703        BXD6 Stem batch1

# %%
# Get the liver metadata
metadata_liver = pd.read_csv(directory_path + "metadata liver.txt", sep="\t")
metadata_liver.head()
# Out:
#     GSM name                   Strain
# 0  GSM436705  Liver_C57BL6J_M_B1_rep1
# 1  GSM436706  Liver_C57BL6J_M_B1_rep2
# 2  GSM436707       Liver_C57BL6J_F_B1
# 3  GSM436708         Liver_DBA2J_F_B1
# 4  GSM436709        Liver_B6D2F1_M_B1

# %%
# Get the gene identifiers for the myeloid alphabet
gene_identifiers_df_myeloid = pd.DataFrame(gse_myeloid.gpls[list(gse_myeloid.gpls.keys())[0]].table)[["ID" , "Symbol"]]
gene_identifiers_df_myeloid.head()
# Out:
#                    ID         Symbol
# 0       GI_38090455-S      LOC382362
# 1  scl0011717.2_283-S          Ampd3
# 2  scl52892.1.1_103-S  D830016O14Rik
# 3    scl0012946.2_3-S           Crry
# 4    scl18939.11_88-S            Ehf

# %%
# Get the gene identifiers for the liver alphabet
gene_identifiers_df_liver= pd.DataFrame(gse_liver.gpls[list(gse_liver.gpls.keys())[0]].table)[["ID" , "GENE_NAME"]]
gene_identifiers_df_liver.head()
# Out:
#              ID                                          GENE_NAME
# 0  A_51_P100021  human immunodeficiency virus type I enhancer b...
# 1  A_51_P100034                            MIF4G domain containing
# 2  A_51_P100052                SLIT and NTRK-like family, member 2
# 3  A_51_P100065                         ligand of numb-protein X 1
# 4  A_51_P100084                                                NaN

# %%
# Get the genotype alphabet
genotype_df = pd.read_csv(directory_path + "genotypes.txt")
genotype_df.head()
# Out:
#    0      Locus  Chr_Build37  Build37_position  BXD1  BXD2  BXD5  BXD6  BXD8  \
# 0  1  rs6269442            1           3482276     0     0     2     2     2
# 1  2  rs6365999            1           4811063     0     0     2     2     2
# 2  3  rs6376963            1           5008090     0     0     2     2     2
# 3  4  rs3677817            1           5176059     0     0     2     2     2
# 4  5  rs8236463            1           5579194     0     0     2     2     2
#
#    BXD9  ...  BXD94  BXD95  BXD96  BXD97  BXD98  BXD99  BXD100  BXD101  \
# 0     0  ...      2      2      0      0      0      0       0       U
# 1     0  ...      2      2      0      0      0      0       0       U
# 2     0  ...      2      2      0      0      0      0       0       U
# 3     0  ...      2      2      0      0      0      0       0       U
# 4     0  ...      2      2      0      0      0      0       0       U
#
#    BXD102  BXD103
# 0       U       U
# 1       U       U
# 2       U       U
# 3       U       U
# 4       U       U
#
# [5 rows x 96 columns]

# %%
# Define useful functions
def parse_gse(gse):
  final_df = pd.DataFrame(columns=["GSM_name", "ID_REF", "VALUE"])
  sample_dfs = []

  # Iterate through each sample
  for gsm_name, gsm in gse.gsms.items():
      sample_data = {
          "GSM_name": gsm_name,
          "ID_REF": gsm.table["ID_REF"],
          "VALUE": gsm.table["VALUE"],
      }
      sample_df = pd.DataFrame(sample_data)
      sample_dfs.append(sample_df)
  final_df = pd.concat(sample_dfs, ignore_index=True)
  return final_df

def merge(df1, df2, left_on, right_on):
    df1 = df1.merge(df2, left_on=left_on, right_on=right_on)
    return df1.drop(columns=[right_on, left_on])

def filter_samples(df, cell_type="Myeloid"):
    # Extract relevant cell types
    df = df[df["Strain"].str.contains(cell_type)]
    # Drop the technical replicates
    df = df[~df["Strain"].str.contains("Technical")]
    df = df[~df["Strain"].str.contains("rep")]
    return df

def pivot_strains(df_merged, index):
    # Pivot the alphabet
    df_pivot = df_merged.pivot_table(columns="Strain", values="VALUE", index=index, aggfunc="mean")
    return df_pivot

def mean_batches(df, cell_type="Myeloid"):
    if cell_type == "Myeloid":
        batch_names = ["a", "b"]
        # Extract strain names from column names
        df.columns = pd.MultiIndex.from_tuples([col.split(' ', 1) for col in df.columns], names=['strain', 'batch'])
        # Calculate the mean across batches for each strain
        mean_df = df.T.groupby(level='strain').mean()
        return mean_df.T
    elif cell_type == "Liver":
        # Mean across sex for each strain
        df.columns = pd.MultiIndex.from_tuples([col.split('_', 2) for col in df.columns],names=['liver','strain','sex'])
        # Calculate the mean across sex for each strain
        mean_df = df.T.groupby(level=['strain']).mean()
        return mean_df.T
    

def mean_strains(df_pivot):
        for strain in df_pivot.columns:
            if strain[-1].lower() == 'a':
                strain_name = strain[:-1]
                if strain_name + 'b' in df_pivot.columns:
                    df_pivot[strain_name] = df_pivot[[strain, strain_name + 'b']].mean(axis=1)
                    df_pivot = df_pivot.drop(columns=[strain, strain_name + 'b'])
                else:
                    df_pivot[strain_name] = df_pivot[strain]
                    df_pivot = df_pivot.drop(columns=[strain])
            elif strain[-1].lower() == 'b' :
                strain_name = strain[:-1]
                if strain_name + 'a' in df_pivot.columns:
                    df_pivot[strain_name] = df_pivot[[strain, strain_name + 'a']].mean(axis=1)
                    df_pivot = df_pivot.drop(columns=[strain, strain_name + 'a'])
        return df_pivot

# %%
# Get the myeloid alphabet
myeloid_df = parse_gse(gse_myeloid)
# Merge the metadata with the alphabet
myeloid_df = merge(myeloid_df, metadata_myeloid, "GSM_name", "GSM name")
# Merge the gene identifiers with the alphabet
myeloid_df = merge(myeloid_df, gene_identifiers_df_myeloid, "ID_REF", "ID")
# Filter the samples to include only the myeloid cells alphabet
myeloid_df = filter_samples(myeloid_df)
# Reshape the alphabet
myeloid_df = pivot_strains(myeloid_df, "Symbol")
# Calculate the mean across batches for each strain
myeloid_df = mean_batches(myeloid_df)
# Merge duplicate strains columns
myeloid_df = mean_strains(myeloid_df)
myeloid_df.head()
# Out:
# strain             BXD1     BXD11     BXD12     BXD13     BXD14     BXD16  \
# Symbol
# 0610005A07Rik  6.439252  6.418787  6.461313  6.459590  6.392369  6.515128
# 0610005C13Rik  6.462294  6.556949  6.591845  6.573851  6.482562  6.616155
# 0610005H09Rik  6.960774  7.096886  7.711693  7.647623  7.651882  7.734397
# 0610005I04     6.532020  6.594255  6.489756  6.697061  6.497515  6.548089
# 0610005K03Rik  7.661794  7.659268  7.786213  7.787414  8.152209  8.030581
#
# strain            BXD18     BXD19      BXD2    BXD21B  ...    BXD32B  \
# Symbol                                                 ...
# 0610005A07Rik  6.446004  6.392673  6.263298  6.318342  ...  6.391703
# 0610005C13Rik  6.494463  6.553485  6.492469  6.409468  ...  6.616821
# 0610005H09Rik  7.822844  7.631427  6.896540  7.810171  ...  8.154312
# 0610005I04     6.637054  6.616757  6.633698  6.774890  ...  6.711600
# 0610005K03Rik  7.836622  8.056267  7.666384  7.882478  ...  7.776629
#
# strain           BXD34B     BXD36     BXD40     BXD42      BXD6      BXD8  \
# Symbol
# 0610005A07Rik  6.414189  6.339669  6.244116  6.322840  6.480558  6.522814
# 0610005C13Rik  6.510064  6.530035  6.591437  6.526547  6.454843  6.496264
# 0610005H09Rik  7.292728  8.094586  8.252535  7.375777  7.562560  7.577809
# 0610005I04     6.488575  6.650941  6.705175  6.630276  6.831132  6.739256
# 0610005K03Rik  8.313372  7.908074  7.922678  7.836622  7.928899  7.988844
#
# strain             BXD9     BXD28     BXD33
# Symbol
# 0610005A07Rik  6.373272  6.529782  6.513522
# 0610005C13Rik  6.586568  6.604400  6.608433
# 0610005H09Rik  7.829545  7.516431  7.651062
# 0610005I04     6.606980  6.953100  6.804694
# 0610005K03Rik  7.882973  7.781489  7.780241
#
# [5 rows x 24 columns]

# %%
relevant_strains = genotype_df.columns[4:]
# Filter the relevant strains to include only those present in myeloid_df
filtered_strains_myeloid = [col for col in relevant_strains if col in myeloid_df.columns]
# Select the filtered columns from myeloid_df
myeloid_df = myeloid_df.loc[:, filtered_strains_myeloid]
# Get only the strains present in myeolid_df from the genotype alphabet
representative_snps_myeloid = genotype_df[filtered_strains_myeloid]
# Now look for snps that have exactly same values for all the strains
duplicates = representative_snps_myeloid[representative_snps_myeloid.duplicated()]
print(f"The number of duplicate SNPs is: {len(duplicates)}")
# Remove the duplicate SNPs
representative_snps_myeloid = representative_snps_myeloid.drop_duplicates()
# Out:
# The number of duplicate SNPs is: 3076

# %%
# Now we have the alphabet in the correct format
# We can start filtering the alphabet
# First, we will filter out the genes with no gene identifier
myeloid_df_filtered = myeloid_df.dropna()
# Then, we will filter out the genes with low variance
row_variance = myeloid_df_filtered.var(axis=1)
average_variance = row_variance.mean()
print(f"The average variance is: {round(average_variance, 3)}")
myeloid_df_filtered = myeloid_df_filtered[row_variance > average_variance/10]
# Now we will filter out the genes with low maximum expression
row_max = myeloid_df_filtered.max(axis=1)
average_max = row_max.mean()
print(f"The average maximum expression value is: {round(average_max, 3)}")
myeloid_df_filtered = myeloid_df_filtered[row_max > average_max-1.2]
print(f"The number of genes before filtering is: {len(myeloid_df)} \nThe number of genes after filtering is: {len(myeloid_df_filtered)}")
myeloid_df_filtered
# Out:
# The average variance is: 0.044
# The average maximum expression value is: 7.661
# The number of genes before filtering is: 33718
# The number of genes after filtering is: 30122
# strain                                         BXD1      BXD2      BXD6  \
# Symbol
# 0610005A07Rik                              6.439252  6.263298  6.480558
# 0610005H09Rik                              6.960774  6.896540  7.562560
# 0610005I04                                 6.532020  6.633698  6.831132
# 0610005K03Rik                              7.661794  7.666384  7.928899
# 0610006F02Rik                              6.839912  6.820642  6.938233
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.429438  6.674736  6.401588
# p                                          6.541973  6.359801  6.517618
# scavenger receptor                         7.106817  7.059044  6.899810
# sty                                        8.787945  8.523423  7.741574
# tea                                        6.494957  6.497032  6.438302
#
# strain                                         BXD8      BXD9     BXD11  \
# Symbol
# 0610005A07Rik                              6.522814  6.373272  6.418787
# 0610005H09Rik                              7.577809  7.829545  7.096886
# 0610005I04                                 6.739256  6.606980  6.594255
# 0610005K03Rik                              7.988844  7.882973  7.659268
# 0610006F02Rik                              6.882953  6.858111  6.752358
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.363483  6.342921  6.566346
# p                                          6.426932  6.535042  6.479159
# scavenger receptor                         6.699562  7.049678  7.526465
# sty                                        9.063488  8.008797  9.646043
# tea                                        6.627027  6.473407  6.454031
#
# strain                                        BXD12     BXD13     BXD14  \
# Symbol
# 0610005A07Rik                              6.461313  6.459590  6.392369
# 0610005H09Rik                              7.711693  7.647623  7.651882
# 0610005I04                                 6.489756  6.697061  6.497515
# 0610005K03Rik                              7.786213  7.787414  8.152209
# 0610006F02Rik                              6.831553  6.860729  6.741501
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.379514  6.349456  6.532331
# p                                          6.212613  6.386862  6.508521
# scavenger receptor                         7.402048  7.746785  6.798596
# sty                                        9.472719  8.881412  9.161894
# tea                                        6.418251  6.405716  6.471698
#
# strain                                        BXD16  ...     BXD19     BXD23  \
# Symbol                                               ...
# 0610005A07Rik                              6.515128  ...  6.392673  6.343721
# 0610005H09Rik                              7.734397  ...  7.631427  7.658030
# 0610005I04                                 6.548089  ...  6.616757  6.640003
# 0610005K03Rik                              8.030581  ...  8.056267  7.920657
# 0610006F02Rik                              6.867071  ...  6.766329  6.935824
# ...                                             ...  ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.577870  ...  6.470454  6.517419
# p                                          6.347702  ...  6.104731  6.359801
# scavenger receptor                         8.034765  ...  6.715678  7.140271
# sty                                        9.242461  ...  9.029700  9.350928
# tea                                        6.501229  ...  6.535940  6.373899
#
# strain                                        BXD27     BXD28     BXD29  \
# Symbol
# 0610005A07Rik                              6.486555  6.529782  6.409871
# 0610005H09Rik                              7.765902  7.516431  7.733955
# 0610005I04                                 6.907307  6.953100  6.727989
# 0610005K03Rik                              7.900948  7.781489  7.869633
# 0610006F02Rik                              6.930366  6.943975  6.996387
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.548269  6.485421  6.447770
# p                                          6.466790  6.642090  6.369591
# scavenger receptor                         6.874077  7.132313  7.834666
# sty                                        9.545547  9.239431  9.492746
# tea                                        6.444591  6.471909  6.478121
#
# strain                                         BXD31     BXD33     BXD36  \
# Symbol
# 0610005A07Rik                               6.494575  6.513522  6.339669
# 0610005H09Rik                               7.371241  7.651062  8.094586
# 0610005I04                                  6.721578  6.804694  6.650941
# 0610005K03Rik                               7.581931  7.780241  7.908074
# 0610006F02Rik                               6.960253  6.991211  6.953835
# ...                                              ...       ...       ...
# neuronal nitric-oxide synthase isoform mu   6.461752  6.479435  6.402252
# p                                           6.415152  6.336126  6.395560
# scavenger receptor                          7.702109  6.960724  6.652632
# sty                                        10.106197  9.241477  8.622802
# tea                                         6.372046  6.570508  6.388176
#
# strain                                        BXD40     BXD42
# Symbol
# 0610005A07Rik                              6.244116  6.322840
# 0610005H09Rik                              8.252535  7.375777
# 0610005I04                                 6.705175  6.630276
# 0610005K03Rik                              7.922678  7.836622
# 0610006F02Rik                              6.831518  7.015863
# ...                                             ...       ...
# neuronal nitric-oxide synthase isoform mu  6.610253  6.398350
# p                                          6.400445  6.347738
# scavenger receptor                         7.252858  6.451716
# sty                                        9.116669  9.550628
# tea                                        6.506383  6.417805
#
# [30122 rows x 21 columns]

# %%
# Get the liver alphabet
liver_df = parse_gse(gse_liver)
# Merge the metadata with the alphabet
liver_df = merge(liver_df, metadata_liver, "GSM_name", "GSM name")
# Merge the gene identifiers with the alphabet
liver_df = merge(liver_df, gene_identifiers_df_liver, "ID_REF", "ID")
# Drop technical replicates
liver_df = filter_samples(liver_df, "Liver")
# Reshape the alphabet
liver_df = pivot_strains(liver_df, "GENE_NAME")
# Calculate the mean across sex for each strain
liver_df = mean_batches(liver_df, "Liver")
liver_df
# Out:
# strain                                                B6D2F1    BXD1  BXD11  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.210833  1.7480  2.243
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.598000  1.7625  1.905
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.421167  0.7030  0.508
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.789833 -2.7585 -2.945
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.886667 -0.6520 -1.477
# ...                                                      ...     ...    ...
# zona pellucida like domain containing 1            -0.206167 -0.1685 -0.153
# zonadhesin                                          0.279500  0.2415  0.438
# zyg-11 homolog A (C. elegans)                       0.458167  0.4280  0.728
# zygote arrest 1                                     0.038667 -0.1490 -0.001
# zyxin                                              -0.307333 -0.5450 -0.866
#
# strain                                              BXD11TY   BXD12   BXD13  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...    1.113  1.2085  1.9485
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...    1.981  1.5790  1.9415
# 1-acylglycerol-3-phosphate O-acyltransferase 3        0.040  0.5605  0.3715
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ...   -2.986 -2.7850 -3.0230
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ...   -1.480 -0.5300 -1.1370
# ...                                                     ...     ...     ...
# zona pellucida like domain containing 1              -0.094 -0.1950 -1.0575
# zonadhesin                                            0.350  0.2925  0.2875
# zyg-11 homolog A (C. elegans)                         0.773  0.3185  0.2415
# zygote arrest 1                                       0.417  0.2700 -0.1700
# zyxin                                                -0.487 -0.5945 -0.7400
#
# strain                                               BXD14   BXD15   BXD16  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  0.9215  1.0310  1.1545
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.3830  1.8660  2.0565
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2740  0.6665  0.4685
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.6615 -2.7080 -3.2560
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.8910 -0.2990 -1.7375
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.0735 -0.2225 -0.0810
# zonadhesin                                          0.3600  0.2525  0.3925
# zyg-11 homolog A (C. elegans)                       0.6095  0.0635  0.6660
# zygote arrest 1                                    -0.1110 -0.0745  0.4875
# zyxin                                              -0.4270 -0.3235 -0.6515
#
# strain                                               BXD19  ...   BXD69  \
# GENE_NAME                                                   ...
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.5565  ...  1.2765
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  2.3185  ...  1.9495
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3900  ...  0.4090
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -3.1915  ... -2.9405
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.6430  ... -1.6545
# ...                                                    ...  ...     ...
# zona pellucida like domain containing 1            -0.1225  ...  0.0140
# zonadhesin                                          0.2340  ...  0.0630
# zyg-11 homolog A (C. elegans)                       0.4840  ...  0.5350
# zygote arrest 1                                    -0.0955  ... -0.0925
# zyxin                                              -0.4150  ... -0.5060
#
# strain                                               BXD73   BXD77    BXD8  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  0.7425  1.4360  1.7245
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.4490  1.8260  2.0670
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2680  0.4305  0.6770
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.8110 -3.0055 -2.9290
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.7400 -0.6750 -0.4900
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1100 -0.3550  0.0940
# zonadhesin                                          0.3440  0.0840  0.2090
# zyg-11 homolog A (C. elegans)                       0.2815  0.7390  0.6840
# zygote arrest 1                                     0.3760  0.3775  0.2995
# zyxin                                              -0.3360 -0.3805 -0.6185
#
# strain                                               BXD85   BXD86    BXD9  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.3890  1.4395  1.1540
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.7725  1.8180  1.2430
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3760  0.4680  0.5405
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -3.1155 -2.9195 -2.7315
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.8610 -0.6505 -0.5690
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1725 -0.3360  0.0930
# zonadhesin                                          0.2685  0.1960  0.7185
# zyg-11 homolog A (C. elegans)                       0.3355  0.6170  0.5690
# zygote arrest 1                                    -0.2295  0.5980 -0.1330
# zyxin                                              -0.4655 -0.1315 -0.5515
#
# strain                                               BXD92  C57BL6J   DBA2J
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.3800  1.12200  1.3166
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.7840  1.75100  1.8952
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2110  0.53600  0.6947
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.9565 -2.92500 -2.6595
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.6770 -0.61000 -1.3286
# ...                                                    ...      ...     ...
# zona pellucida like domain containing 1            -0.1780 -0.03725 -0.0173
# zonadhesin                                          0.0780  0.40250  0.3905
# zyg-11 homolog A (C. elegans)                       0.6635  0.44575  0.2731
# zygote arrest 1                                    -0.1920 -0.19500  0.1497
# zyxin                                              -0.3000 -0.45625 -0.4278
#
# [17917 rows x 44 columns]

# %%
# Filter the relevant strains to include only those present in liver_df
filtered_strains_liver = [col for col in relevant_strains if col in liver_df.columns]
# Select the filtered columns from liver_df
liver_df = liver_df.loc[:, filtered_strains_liver]
# Get only the strains present in liver_df from the genotype alphabet
# Filter the genotype alphabet to include only the relevant strains
representative_snps_liver = genotype_df[filtered_strains_liver]
# Now look for snps that have exactly same values for all the strains
duplicates = representative_snps_liver[representative_snps_liver.duplicated()]
print(f"The number of duplicate SNPs is: {len(duplicates)}")
# Remove the duplicate SNPs
representative_snps_liver = representative_snps_liver.drop_duplicates()
# Out:
# The number of duplicate SNPs is: 2424

# %%
# Filtering for liver alphabet
liver_df_filtered = liver_df.dropna()
row_variance = liver_df_filtered.var(axis=1)
average_variance = row_variance.mean()
print(f"The average variance is: {round(average_variance, 3)}")
liver_df_filtered = liver_df_filtered[row_variance > average_variance/10]
row_max = liver_df_filtered.max(axis=1)
average_max = row_max.mean()
print(f"The average maximum expression value is: {round(average_max, 3)}")
liver_df_filtered = liver_df_filtered[row_max > average_max-2]
print(f"The number of genes before filtering is: {len(liver_df)} \nThe number of genes after filtering is: {len(liver_df_filtered)}")
liver_df_filtered
# Out:
# The average variance is: 0.055
# The average maximum expression value is: 0.275
# The number of genes before filtering is: 17917
# The number of genes after filtering is: 16864
# strain                                                BXD1    BXD2    BXD5  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.7480  1.1440  0.8800
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.7625  1.8615  1.7190
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.7030  0.2645  0.6325
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.6520 -0.1725 -1.1295
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  0.8450  0.7320  1.1730
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1685 -0.1325 -0.4075
# zonadhesin                                          0.2415  0.3035  0.2125
# zyg-11 homolog A (C. elegans)                       0.4280  0.8640  0.2355
# zygote arrest 1                                    -0.1490  0.3805  0.4180
# zyxin                                              -0.5450 -0.6260 -0.2665
#
# strain                                                BXD6    BXD8    BXD9  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.2030  1.7245  1.1540
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.6200  2.0670  1.2430
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3815  0.6770  0.5405
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.4600 -0.4900 -0.5690
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  0.9065  1.1170  1.6770
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.3370  0.0940  0.0930
# zonadhesin                                          0.3725  0.2090  0.7185
# zyg-11 homolog A (C. elegans)                       0.3880  0.6840  0.5690
# zygote arrest 1                                     0.4005  0.2995 -0.1330
# zyxin                                              -0.2855 -0.6185 -0.5515
#
# strain                                              BXD11   BXD12   BXD13  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  2.243  1.2085  1.9485
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.905  1.5790  1.9415
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.508  0.5605  0.3715
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.477 -0.5300 -1.1370
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  1.267  1.2195  1.4020
# ...                                                   ...     ...     ...
# zona pellucida like domain containing 1            -0.153 -0.1950 -1.0575
# zonadhesin                                          0.438  0.2925  0.2875
# zyg-11 homolog A (C. elegans)                       0.728  0.3185  0.2415
# zygote arrest 1                                    -0.001  0.2700 -0.1700
# zyxin                                              -0.866 -0.5945 -0.7400
#
# strain                                               BXD14  ...   BXD48  \
# GENE_NAME                                                   ...
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  0.9215  ...  0.8665
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.3830  ...  2.1070
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2740  ...  0.2860
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.8910  ... -0.5345
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  0.9095  ...  0.8305
# ...                                                    ...  ...     ...
# zona pellucida like domain containing 1            -0.0735  ... -0.1560
# zonadhesin                                          0.3600  ...  0.3075
# zyg-11 homolog A (C. elegans)                       0.6095  ...  0.4615
# zygote arrest 1                                    -0.1110  ...  0.5390
# zyxin                                              -0.4270  ... -0.6000
#
# strain                                               BXD51   BXD60   BXD62  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  0.9135  1.0820  0.9410
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.9635  1.5355  1.7440
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3145  0.5700  0.5715
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.7830 -1.2535 -0.7695
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  1.1930  0.9895  1.6265
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1410 -0.0850 -0.1955
# zonadhesin                                          0.2205  0.2730  0.2175
# zyg-11 homolog A (C. elegans)                       0.5400  0.3875  0.5035
# zygote arrest 1                                     0.4385  0.2885  0.3260
# zyxin                                              -0.1405 -0.3165 -0.2665
#
# strain                                               BXD69   BXD73   BXD77  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.2765  0.7425  1.4360
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.9495  1.4490  1.8260
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.4090  0.2680  0.4305
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.6545 -1.7400 -0.6750
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  1.3075  1.7400  0.9195
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1             0.0140 -0.1100 -0.3550
# zonadhesin                                          0.0630  0.3440  0.0840
# zyg-11 homolog A (C. elegans)                       0.5350  0.2815  0.7390
# zygote arrest 1                                    -0.0925  0.3760  0.3775
# zyxin                                              -0.5060 -0.3360 -0.3805
#
# strain                                               BXD85   BXD86   BXD92
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.3890  1.4395  1.3800
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.7725  1.8180  1.7840
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3760  0.4680  0.2110
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.8610 -0.6505 -0.6770
# 1-acylglycerol-3-phosphate O-acyltransferase 6 ...  1.2785  0.9790  1.3175
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1725 -0.3360 -0.1780
# zonadhesin                                          0.2685  0.1960  0.0780
# zyg-11 homolog A (C. elegans)                       0.3355  0.6170  0.6635
# zygote arrest 1                                    -0.2295  0.5980 -0.1920
# zyxin                                              -0.4655 -0.1315 -0.3000
#
# [16864 rows x 40 columns]

# %%
# Function for the analysis 
def association_test(df, snps):
    eQTLs = []
    for gene in df.index:
        # Run the regression
        results = f_regression(snps.T, df.loc[gene].T)
        # Get the p-values
        p_values = results[1]
        eQTLs.append({"gene": gene, "p_values": p_values})
    eQTLs_df = pd.DataFrame(eQTLs)
    return eQTLs_df

def correct_results(df1, df2):
    # Merge the p-values columns for FDR correction
    p_merged = pd.concat([df1['p_values'], df2['p_values']], axis=0)
    p_values = list(chain.from_iterable(p_merged))
    
    # Correct the p-values for multiple testing
    corrected_p_values = fdrcorrection(p_values)[1]
    
    # Initialize new columns in both dataframes
    df1["corrected_p_values"] = [None] * len(df1)
    df1["significant_snps"] = [None] * len(df1)
    df2["corrected_p_values"] = [None] * len(df2)
    df2["significant_snps"] = [None] * len(df2)
    
    # Separate corrected p-values for each dataframe
    n_snps1 = len(df1.loc[0, "p_values"])
    n_snps2 = len(df2.loc[0, "p_values"])
    
    corrected_p_values1 = corrected_p_values[:len(df1) * n_snps1]
    corrected_p_values2 = corrected_p_values[len(df1) * n_snps1:]
    
    # Assign corrected p-values and significant SNPs
    for i in range(len(df1)):
        start = i * n_snps1
        end = (i + 1) * n_snps1
        df1.at[i, "corrected_p_values"] = corrected_p_values1[start:end]
        df1.at[i, "significant_snps"] = {genotype_df.loc[snp_idx, 'Locus']: p 
                                         for snp_idx, p in enumerate(corrected_p_values1[start:end]) if p < 0.05}
    
    for i in range(len(df2)):
        start = i * n_snps2
        end = (i + 1) * n_snps2
        df2.at[i, "corrected_p_values"] = corrected_p_values2[start:end]
        df2.at[i, "significant_snps"] = {genotype_df.loc[snp_idx, 'Locus']: p 
                                         for snp_idx, p in enumerate(corrected_p_values2[start:end]) if p < 0.05}
    
    # Drop genes with no significant SNPs
    eQTLs_df1 = df1[df1["significant_snps"].map(lambda d: len(d)) > 0].reset_index(drop=True)
    eQTLs_df2 = df2[df2["significant_snps"].map(lambda d: len(d)) > 0].reset_index(drop=True)
    
    return eQTLs_df1, eQTLs_df2


def eqtl_analysis(df1, df2, snps1, snps2):
    eQTLs1 = association_test(df1, snps1)
    eQTLs2 = association_test(df2, snps2)
    eQTLs_corrected1, eQTLs_corrected2 = correct_results(eQTLs1, eQTLs2)
    return eQTLs_corrected1, eQTLs_corrected2

# %%
# Run the eQTL analysis
eQTLs_myeloid, eQTLs_liver = eqtl_analysis(myeloid_df_filtered, liver_df_filtered, representative_snps_myeloid, representative_snps_liver)
eQTLs_myeloid.head()
# Out:
#             gene                                           p_values  \
# 0  0610009K11Rik  [0.7873410843132229, 0.8146248196203343, 0.903...
# 1  0710001D07Rik  [0.5113191855604085, 0.9841955580636499, 0.852...
# 2  1110001E17Rik  [0.42799892033109144, 0.698007729042269, 0.313...
# 3  1110003E01Rik  [0.9394831525677712, 0.9875195913130943, 0.585...
# 4  1110003F05Rik  [0.0062575741664354576, 0.02298229911840907, 0...
#
#                                   corrected_p_values  \
# 0  [0.9936389945208776, 0.9945867590017438, 0.997...
# 1  [0.9816872876639764, 0.9995894401713452, 0.995...
# 2  [0.9772561651921646, 0.990235038035205, 0.9703...
# 3  [0.9984314843536239, 0.9996823519891541, 0.985...
# 4  [0.8568268500457448, 0.9154534596026077, 0.842...
#
#                                     significant_snps
# 0  {'rs3667720': 0.03810062116258838, 'rs13476083...
# 1  {'rs3726974': 0.00017985910254448507, 'rs31438...
# 2               {'rs13476315': 0.026984285342278033}
# 3  {'rs13476118': 0.008429474007565099, 'rs134761...
# 4                   {'D1Mit294': 0.0487819157620498}

# %%
eQTLs_liver.head()
# Out:
#                                                 gene  \
# 0  1-acylglycerol-3-phosphate O-acyltransferase 5...
# 1     1-acylglycerol-3-phosphate O-acyltransferase 9
# 2      2',3'-cyclic nucleotide 3' phosphodiesterase"
# 3                 2'-5' oligoadenylate synthetase 1C
# 4   3-hydroxy-3-methylglutaryl-Coenzyme A synthase 1
#
#                                             p_values  \
# 0  [0.8231205823389012, 0.9384462933247342, 0.662...
# 1  [0.41408148322813854, 0.33823247465348305, 0.8...
# 2  [0.16864091640940057, 0.08769081945237145, 0.2...
# 3  [0.00010081372774950156, 0.000528171112483109,...
# 4  [0.513470486979324, 0.6258490256587621, 0.4778...
#
#                                   corrected_p_values  \
# 0  [0.9948606669580963, 0.9984035097639842, 0.988...
# 1  [0.9764860823745213, 0.9717115103325055, 0.995...
# 2  [0.9585972268523969, 0.9465455399806717, 0.968...
# 3  [0.27395850104159125, 0.5582374436424771, 0.88...
# 4  [0.981810618738754, 0.9871111157664438, 0.9799...
#
#                                     significant_snps
# 0  {'rs13476898': 0.019543743198308247, 'rs621910...
# 1  {'CEL-2_50605053': 0.0019472312833531023, 'rs1...
# 2           {'CEL-6_17260153': 0.030412039228340775}
# 3  {'rs6201380': 0.020337933483872327, 'gnf01.013...
# 4                {'rs3659850': 0.002031989164650012}

# %%
eQTLs_counter = Counter()
for eqtl in pd.concat([eQTLs_myeloid['significant_snps'], eQTLs_liver['significant_snps']], axis=0):
    eQTLs_counter.update(eqtl.keys())
eqtls_number = len(eQTLs_counter)
print(f"There are {eqtls_number} eQTLs")
# Out:
# There are 1179 eQTLs

# %%
eQTLs_counter
