# %% [markdown]
# # Assignment 3 in System Genetics - Gil Sasson & Tomer Schweid

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import GEOparse
from sklearn.feature_selection import f_regression
from statsmodels.stats.multitest import fdrcorrection
from itertools import chain
from collections import Counter

# %% [markdown]
# # Part A: eQTL analysis

# %% [markdown]
# ## Preprocessing

# %%
directory_path = "/Users/gilsasson/Library/CloudStorage/OneDrive-mail.tau.ac.il/ביולוגיה ומדעי המוח/שנה ג/סמסטר ב/גנטיקה בעידן הרפואה האישית/Assignments/Assignment 3/"

# %%
# Download the alphabet
gse_myeloid = GEOparse.get_GEO(geo='GSE18067', destdir=directory_path)
gse_liver = GEOparse.get_GEO(geo='GSE17522', destdir=directory_path)
# Out:
# 08-Aug-2024 20:41:50 DEBUG utils - Directory /Users/gilsasson/Library/CloudStorage/OneDrive-mail.tau.ac.il/ביולוגיה ומדעי המוח/שנה ג/סמסטר ב/גנטיקה בעידן הרפואה האישית/Assignments/Assignment 3/ already exists. Skipping.
# 08-Aug-2024 20:41:50 INFO GEOparse - File already exist: using local version.
# 08-Aug-2024 20:41:50 INFO GEOparse - Parsing /Users/gilsasson/Library/CloudStorage/OneDrive-mail.tau.ac.il/ביולוגיה ומדעי המוח/שנה ג/סמסטר ב/גנטיקה בעידן הרפואה האישית/Assignments/Assignment 3/GSE18067_family.soft.gz:
# 08-Aug-2024 20:41:50 DEBUG GEOparse - DATABASE: GeoMiame
# 08-Aug-2024 20:41:50 DEBUG GEOparse - SERIES: GSE18067
# 08-Aug-2024 20:41:50 DEBUG GEOparse - PLATFORM: GPL6238
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451699
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451700
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451701
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451702
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451703
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451704
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451705
# 08-Aug-2024 20:41:51 DEBUG GEOparse - SAMPLE: GSM451706
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451707
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451708
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451709
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451710
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451711
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451712
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451713
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451714
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451715
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451716
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451717
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451718
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451719
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451720
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451721
# 08-Aug-2024 20:41:52 DEBUG GEOparse - SAMPLE: GSM451722
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451723
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451724
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451725
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451726
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451727
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451728
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451729
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451730
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451731
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451732
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451733
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451734
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451735
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451736
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451737
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451738
# 08-Aug-2024 20:41:53 DEBUG GEOparse - SAMPLE: GSM451739
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451740
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451741
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451742
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451743
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451744
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451745
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451746
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451747
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451748
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451749
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451750
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451751
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451752
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451753
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451754
# 08-Aug-2024 20:41:54 DEBUG GEOparse - SAMPLE: GSM451755
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451756
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451757
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451758
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451759
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451760
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451761
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451762
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451763
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451764
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451765
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451766
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451767
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451768
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451769
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451770
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451771
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451772
# 08-Aug-2024 20:41:55 DEBUG GEOparse - SAMPLE: GSM451773
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451774
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451775
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451776
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451777
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451778
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451779
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451780
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451781
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451782
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451783
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451784
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451785
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451786
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451787
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451788
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451789
# 08-Aug-2024 20:41:56 DEBUG GEOparse - SAMPLE: GSM451790
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451791
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451792
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451793
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451794
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451795
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451796
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451797
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM451798
# 08-Aug-2024 20:41:57 DEBUG utils - Directory /Users/gilsasson/Library/CloudStorage/OneDrive-mail.tau.ac.il/ביולוגיה ומדעי המוח/שנה ג/סמסטר ב/גנטיקה בעידן הרפואה האישית/Assignments/Assignment 3/ already exists. Skipping.
# 08-Aug-2024 20:41:57 INFO GEOparse - File already exist: using local version.
# 08-Aug-2024 20:41:57 INFO GEOparse - Parsing /Users/gilsasson/Library/CloudStorage/OneDrive-mail.tau.ac.il/ביולוגיה ומדעי המוח/שנה ג/סמסטר ב/גנטיקה בעידן הרפואה האישית/Assignments/Assignment 3/GSE17522_family.soft.gz:
# 08-Aug-2024 20:41:57 DEBUG GEOparse - DATABASE: GeoMiame
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SERIES: GSE17522
# 08-Aug-2024 20:41:57 DEBUG GEOparse - PLATFORM: GPL6466
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436705
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436706
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436707
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436708
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436709
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436710
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436711
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436712
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436713
# 08-Aug-2024 20:41:57 DEBUG GEOparse - SAMPLE: GSM436714
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436715
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436716
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436717
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436718
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436719
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436720
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436721
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436722
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436723
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436724
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436725
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436726
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436727
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436728
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436729
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436730
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436731
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436732
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436733
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436734
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436735
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436736
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436737
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436738
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436739
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436740
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436741
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436742
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436743
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436744
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436745
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436746
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436747
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436748
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436749
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436750
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436751
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436752
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436753
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436754
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436755
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436756
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436757
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436758
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436759
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436760
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436761
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436762
# 08-Aug-2024 20:41:58 DEBUG GEOparse - SAMPLE: GSM436763
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436764
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436765
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436766
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436767
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436768
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436769
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436770
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436771
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436772
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436773
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436774
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436775
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436776
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436777
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436778
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436779
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436780
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436781
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436782
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436783
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436784
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436785
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436786
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436787
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436788
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436789
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436790
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436791
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436792
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436793
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436794
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436795
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436796
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436797
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436798
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436799
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436800
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436801
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436802
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436803
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436804
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436805
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436806
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436807
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436808
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436809
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436810
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436811
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436812
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436813
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436814
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436815
# 08-Aug-2024 20:41:59 DEBUG GEOparse - SAMPLE: GSM436816
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436817
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436818
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436819
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436820
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436821
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436822
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436823
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436824
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436825
# 08-Aug-2024 20:42:00 DEBUG GEOparse - SAMPLE: GSM436826

# %%
# Get the myeloid metadata
metadata_myeloid = pd.read_csv(directory_path + "metadata myeloid.txt", sep="\t")
metadata_myeloid.head()
# Out:
#     GSM name                  Strain
# 0  GSM451699    BXD13 Myeloid batch1
# 1  GSM451700  BXD23 Erythroid batch1
# 2  GSM451701  BXD40 Erythroid batch1
# 3  GSM451702    BXD36 Myeloid batch1
# 4  GSM451703        BXD6 Stem batch1

# %%
# Get the liver metadata
metadata_liver = pd.read_csv(directory_path + "metadata liver.txt", sep="\t")
metadata_liver.head()
# Out:
#     GSM name                   Strain
# 0  GSM436705  Liver_C57BL6J_M_B1_rep1
# 1  GSM436706  Liver_C57BL6J_M_B1_rep2
# 2  GSM436707       Liver_C57BL6J_F_B1
# 3  GSM436708         Liver_DBA2J_F_B1
# 4  GSM436709        Liver_B6D2F1_M_B1

# %%
# Get the gene identifiers for the myeloid alphabet
gene_identifiers_df_myeloid = pd.DataFrame(gse_myeloid.gpls[list(gse_myeloid.gpls.keys())[0]].table)[["ID" , "Symbol"]]
gene_identifiers_df_myeloid.head()
# Out:
#                    ID         Symbol
# 0       GI_38090455-S      LOC382362
# 1  scl0011717.2_283-S          Ampd3
# 2  scl52892.1.1_103-S  D830016O14Rik
# 3    scl0012946.2_3-S           Crry
# 4    scl18939.11_88-S            Ehf

# %%
# Get the gene identifiers for the liver alphabet
gene_identifiers_df_liver= pd.DataFrame(gse_liver.gpls[list(gse_liver.gpls.keys())[0]].table)[["ID" , "GENE_NAME"]]
gene_identifiers_df_liver.head()
# Out:
#              ID                                          GENE_NAME
# 0  A_51_P100021  human immunodeficiency virus type I enhancer b...
# 1  A_51_P100034                            MIF4G domain containing
# 2  A_51_P100052                SLIT and NTRK-like family, member 2
# 3  A_51_P100065                         ligand of numb-protein X 1
# 4  A_51_P100084                                                NaN

# %%
# Get the genotype alphabet
genotype_df = pd.read_csv(directory_path + "genotypes.txt")
genotype_df.head()
# Out:
#    0      Locus  Chr_Build37  Build37_position  BXD1  BXD2  BXD5  BXD6  BXD8  \
# 0  1  rs6269442            1           3482276     0     0     2     2     2
# 1  2  rs6365999            1           4811063     0     0     2     2     2
# 2  3  rs6376963            1           5008090     0     0     2     2     2
# 3  4  rs3677817            1           5176059     0     0     2     2     2
# 4  5  rs8236463            1           5579194     0     0     2     2     2
#
#    BXD9  ...  BXD94  BXD95  BXD96  BXD97  BXD98  BXD99  BXD100  BXD101  \
# 0     0  ...      2      2      0      0      0      0       0       U
# 1     0  ...      2      2      0      0      0      0       0       U
# 2     0  ...      2      2      0      0      0      0       0       U
# 3     0  ...      2      2      0      0      0      0       0       U
# 4     0  ...      2      2      0      0      0      0       0       U
#
#    BXD102  BXD103
# 0       U       U
# 1       U       U
# 2       U       U
# 3       U       U
# 4       U       U
#
# [5 rows x 96 columns]

# %%
# Define useful functions
def parse_gse(gse):
  final_df = pd.DataFrame(columns=["GSM_name", "ID_REF", "VALUE"])
  sample_dfs = []

  # Iterate through each sample
  for gsm_name, gsm in gse.gsms.items():
      sample_data = {
          "GSM_name": gsm_name,
          "ID_REF": gsm.table["ID_REF"],
          "VALUE": gsm.table["VALUE"],
      }
      sample_df = pd.DataFrame(sample_data)
      sample_dfs.append(sample_df)
  final_df = pd.concat(sample_dfs, ignore_index=True)
  return final_df

def merge(df1, df2, left_on, right_on):
    df1 = df1.merge(df2, left_on=left_on, right_on=right_on)
    return df1.drop(columns=[right_on, left_on])

def filter_samples(df, cell_type="Myeloid"):
    # Extract relevant cell types
    df = df[df["Strain"].str.contains(cell_type)]
    # Drop the technical replicates
    df = df[~df["Strain"].str.contains("Technical")]
    df = df[~df["Strain"].str.contains("rep")]
    return df

def pivot_strains(df_merged, index):
    # Pivot the alphabet
    df_pivot = df_merged.pivot_table(columns="Strain", values="VALUE", index=index, aggfunc="mean")
    return df_pivot

def mean_batches(df, cell_type="Myeloid"):
    if cell_type == "Myeloid":
        batch_names = ["a", "b"]
        # Extract strain names from column names
        df.columns = pd.MultiIndex.from_tuples([col.split(' ', 1) for col in df.columns], names=['strain', 'batch'])
        # Calculate the mean across batches for each strain
        mean_df = df.T.groupby(level='strain').mean()
        return mean_df.T
    elif cell_type == "Liver":
        # Mean across sex for each strain
        df.columns = pd.MultiIndex.from_tuples([col.split('_', 2) for col in df.columns],names=['liver','strain','sex'])
        # Calculate the mean across sex for each strain
        mean_df = df.T.groupby(level=['strain']).mean()
        return mean_df.T
    

def mean_strains(df_pivot):
        for strain in df_pivot.columns:
            if strain[-1].lower() == 'a':
                strain_name = strain[:-1]
                if strain_name + 'b' in df_pivot.columns:
                    df_pivot[strain_name] = df_pivot[[strain, strain_name + 'b']].mean(axis=1)
                    df_pivot = df_pivot.drop(columns=[strain, strain_name + 'b'])
                else:
                    df_pivot[strain_name] = df_pivot[strain]
                    df_pivot = df_pivot.drop(columns=[strain])
            elif strain[-1].lower() == 'b' :
                strain_name = strain[:-1]
                if strain_name + 'a' in df_pivot.columns:
                    df_pivot[strain_name] = df_pivot[[strain, strain_name + 'a']].mean(axis=1)
                    df_pivot = df_pivot.drop(columns=[strain, strain_name + 'a'])
        return df_pivot

# %%
# Get the  myeloid alphabet
myeloid_df = parse_gse(gse_myeloid)
# Merge the metadata with the alphabet
myeloid_df = merge(myeloid_df, metadata_myeloid, "GSM_name", "GSM name")
# Merge the gene identifiers with the alphabet
myeloid_df = merge(myeloid_df, gene_identifiers_df_myeloid, "ID_REF", "ID")
# Filter the samples to include only the myeloid cells alphabet
myeloid_df = filter_samples(myeloid_df)
# Reshape the alphabet
myeloid_df = pivot_strains(myeloid_df, "Symbol")
# Calculate the mean across batches for each strain
myeloid_df = mean_batches(myeloid_df)
# Merge duplicate strains columns
myeloid_df = mean_strains(myeloid_df)
myeloid_df.head()
# Out:
# strain             BXD1     BXD11     BXD12     BXD13     BXD14     BXD16  \
# Symbol
# 0610005A07Rik  6.439252  6.418787  6.461313  6.459590  6.392369  6.515128
# 0610005C13Rik  6.462294  6.556949  6.591845  6.573851  6.482562  6.616155
# 0610005H09Rik  6.960774  7.096886  7.711693  7.647623  7.651882  7.734397
# 0610005I04     6.532020  6.594255  6.489756  6.697061  6.497515  6.548089
# 0610005K03Rik  7.661794  7.659268  7.786213  7.787414  8.152209  8.030581
#
# strain            BXD18     BXD19      BXD2    BXD21B  ...    BXD32B  \
# Symbol                                                 ...
# 0610005A07Rik  6.446004  6.392673  6.263298  6.318342  ...  6.391703
# 0610005C13Rik  6.494463  6.553485  6.492469  6.409468  ...  6.616821
# 0610005H09Rik  7.822844  7.631427  6.896540  7.810171  ...  8.154312
# 0610005I04     6.637054  6.616757  6.633698  6.774890  ...  6.711600
# 0610005K03Rik  7.836622  8.056267  7.666384  7.882478  ...  7.776629
#
# strain           BXD34B     BXD36     BXD40     BXD42      BXD6      BXD8  \
# Symbol
# 0610005A07Rik  6.414189  6.339669  6.244116  6.322840  6.480558  6.522814
# 0610005C13Rik  6.510064  6.530035  6.591437  6.526547  6.454843  6.496264
# 0610005H09Rik  7.292728  8.094586  8.252535  7.375777  7.562560  7.577809
# 0610005I04     6.488575  6.650941  6.705175  6.630276  6.831132  6.739256
# 0610005K03Rik  8.313372  7.908074  7.922678  7.836622  7.928899  7.988844
#
# strain             BXD9     BXD28     BXD33
# Symbol
# 0610005A07Rik  6.373272  6.529782  6.513522
# 0610005C13Rik  6.586568  6.604400  6.608433
# 0610005H09Rik  7.829545  7.516431  7.651062
# 0610005I04     6.606980  6.953100  6.804694
# 0610005K03Rik  7.882973  7.781489  7.780241
#
# [5 rows x 24 columns]

# %%
relevant_strains = genotype_df.columns[4:]
# Filter the relevant strains to include only those present in myeloid_df
filtered_strains_myeloid = [col for col in relevant_strains if col in myeloid_df.columns]
# Select the filtered columns from myeloid_df
myeloid_df = myeloid_df.loc[:, filtered_strains_myeloid]
# Get only the strains present in myeolid_df from the genotype alphabet
representative_snps_myeloid = genotype_df[filtered_strains_myeloid]
# Now look for snps that have exactly same values for all the strains
duplicates = representative_snps_myeloid[representative_snps_myeloid.duplicated()]
print(f"The number of duplicate SNPs is: {len(duplicates)}")
# Remove the duplicate SNPs
representative_snps_myeloid = representative_snps_myeloid.drop_duplicates()
# Out:
# The number of duplicate SNPs is: 3076

# %%
# Now we have the alphabet in the correct format
# We can start filtering the alphabet
# First, we will filter out the genes with no gene identifier
myeloid_df_filtered = myeloid_df.dropna()
# Then, we will filter out the genes with low variance
row_variance = myeloid_df_filtered.var(axis=1)
average_variance = row_variance.mean()
print(f"The average variance is: {round(average_variance, 3)}")
myeloid_df_filtered = myeloid_df[row_variance > average_variance/10]
# Now we will filter out the genes with low maximum expression
row_max = myeloid_df_filtered.max(axis=1)
average_max = row_max.mean()
print(f"The average maximum expression value is: {round(average_max, 3)}")
myeloid_df_filtered = myeloid_df_filtered[row_max > average_max-1.2]
print(f"The number of genes before filtering is: {len(myeloid_df)} \nThe number of genes after filtering is: {len(myeloid_df_filtered)}")
myeloid_df_filtered
# Out:
# The average variance is: 0.044
# The average maximum expression value is: 7.661
# The number of genes before filtering is: 33718
# The number of genes after filtering is: 30122
# strain                                         BXD1      BXD2      BXD6  \
# Symbol
# 0610005A07Rik                              6.439252  6.263298  6.480558
# 0610005H09Rik                              6.960774  6.896540  7.562560
# 0610005I04                                 6.532020  6.633698  6.831132
# 0610005K03Rik                              7.661794  7.666384  7.928899
# 0610006F02Rik                              6.839912  6.820642  6.938233
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.429438  6.674736  6.401588
# p                                          6.541973  6.359801  6.517618
# scavenger receptor                         7.106817  7.059044  6.899810
# sty                                        8.787945  8.523423  7.741574
# tea                                        6.494957  6.497032  6.438302
#
# strain                                         BXD8      BXD9     BXD11  \
# Symbol
# 0610005A07Rik                              6.522814  6.373272  6.418787
# 0610005H09Rik                              7.577809  7.829545  7.096886
# 0610005I04                                 6.739256  6.606980  6.594255
# 0610005K03Rik                              7.988844  7.882973  7.659268
# 0610006F02Rik                              6.882953  6.858111  6.752358
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.363483  6.342921  6.566346
# p                                          6.426932  6.535042  6.479159
# scavenger receptor                         6.699562  7.049678  7.526465
# sty                                        9.063488  8.008797  9.646043
# tea                                        6.627027  6.473407  6.454031
#
# strain                                        BXD12     BXD13     BXD14  \
# Symbol
# 0610005A07Rik                              6.461313  6.459590  6.392369
# 0610005H09Rik                              7.711693  7.647623  7.651882
# 0610005I04                                 6.489756  6.697061  6.497515
# 0610005K03Rik                              7.786213  7.787414  8.152209
# 0610006F02Rik                              6.831553  6.860729  6.741501
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.379514  6.349456  6.532331
# p                                          6.212613  6.386862  6.508521
# scavenger receptor                         7.402048  7.746785  6.798596
# sty                                        9.472719  8.881412  9.161894
# tea                                        6.418251  6.405716  6.471698
#
# strain                                        BXD16  ...     BXD19     BXD23  \
# Symbol                                               ...
# 0610005A07Rik                              6.515128  ...  6.392673  6.343721
# 0610005H09Rik                              7.734397  ...  7.631427  7.658030
# 0610005I04                                 6.548089  ...  6.616757  6.640003
# 0610005K03Rik                              8.030581  ...  8.056267  7.920657
# 0610006F02Rik                              6.867071  ...  6.766329  6.935824
# ...                                             ...  ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.577870  ...  6.470454  6.517419
# p                                          6.347702  ...  6.104731  6.359801
# scavenger receptor                         8.034765  ...  6.715678  7.140271
# sty                                        9.242461  ...  9.029700  9.350928
# tea                                        6.501229  ...  6.535940  6.373899
#
# strain                                        BXD27     BXD28     BXD29  \
# Symbol
# 0610005A07Rik                              6.486555  6.529782  6.409871
# 0610005H09Rik                              7.765902  7.516431  7.733955
# 0610005I04                                 6.907307  6.953100  6.727989
# 0610005K03Rik                              7.900948  7.781489  7.869633
# 0610006F02Rik                              6.930366  6.943975  6.996387
# ...                                             ...       ...       ...
# neuronal nitric-oxide synthase isoform mu  6.548269  6.485421  6.447770
# p                                          6.466790  6.642090  6.369591
# scavenger receptor                         6.874077  7.132313  7.834666
# sty                                        9.545547  9.239431  9.492746
# tea                                        6.444591  6.471909  6.478121
#
# strain                                         BXD31     BXD33     BXD36  \
# Symbol
# 0610005A07Rik                               6.494575  6.513522  6.339669
# 0610005H09Rik                               7.371241  7.651062  8.094586
# 0610005I04                                  6.721578  6.804694  6.650941
# 0610005K03Rik                               7.581931  7.780241  7.908074
# 0610006F02Rik                               6.960253  6.991211  6.953835
# ...                                              ...       ...       ...
# neuronal nitric-oxide synthase isoform mu   6.461752  6.479435  6.402252
# p                                           6.415152  6.336126  6.395560
# scavenger receptor                          7.702109  6.960724  6.652632
# sty                                        10.106197  9.241477  8.622802
# tea                                         6.372046  6.570508  6.388176
#
# strain                                        BXD40     BXD42
# Symbol
# 0610005A07Rik                              6.244116  6.322840
# 0610005H09Rik                              8.252535  7.375777
# 0610005I04                                 6.705175  6.630276
# 0610005K03Rik                              7.922678  7.836622
# 0610006F02Rik                              6.831518  7.015863
# ...                                             ...       ...
# neuronal nitric-oxide synthase isoform mu  6.610253  6.398350
# p                                          6.400445  6.347738
# scavenger receptor                         7.252858  6.451716
# sty                                        9.116669  9.550628
# tea                                        6.506383  6.417805
#
# [30122 rows x 21 columns]

# %%
# Get the liver alphabet
liver_df = parse_gse(gse_liver)
# Merge the metadata with the alphabet
liver_df = merge(liver_df, metadata_liver, "GSM_name", "GSM name")
# Merge the gene identifiers with the alphabet
liver_df = merge(liver_df, gene_identifiers_df_liver, "ID_REF", "ID")
# Drop technical replicates
liver_df = filter_samples(liver_df, "Liver")
# Reshape the alphabet
liver_df = pivot_strains(liver_df, "GENE_NAME")
# Calculate the mean across sex for each strain
liver_df = mean_batches(liver_df, "Liver")
liver_df
# Out:
# strain                                                B6D2F1    BXD1  BXD11  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.210833  1.7480  2.243
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.598000  1.7625  1.905
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.421167  0.7030  0.508
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.789833 -2.7585 -2.945
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.886667 -0.6520 -1.477
# ...                                                      ...     ...    ...
# zona pellucida like domain containing 1            -0.206167 -0.1685 -0.153
# zonadhesin                                          0.279500  0.2415  0.438
# zyg-11 homolog A (C. elegans)                       0.458167  0.4280  0.728
# zygote arrest 1                                     0.038667 -0.1490 -0.001
# zyxin                                              -0.307333 -0.5450 -0.866
#
# strain                                              BXD11TY   BXD12   BXD13  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...    1.113  1.2085  1.9485
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...    1.981  1.5790  1.9415
# 1-acylglycerol-3-phosphate O-acyltransferase 3        0.040  0.5605  0.3715
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ...   -2.986 -2.7850 -3.0230
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ...   -1.480 -0.5300 -1.1370
# ...                                                     ...     ...     ...
# zona pellucida like domain containing 1              -0.094 -0.1950 -1.0575
# zonadhesin                                            0.350  0.2925  0.2875
# zyg-11 homolog A (C. elegans)                         0.773  0.3185  0.2415
# zygote arrest 1                                       0.417  0.2700 -0.1700
# zyxin                                                -0.487 -0.5945 -0.7400
#
# strain                                               BXD14   BXD15   BXD16  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  0.9215  1.0310  1.1545
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.3830  1.8660  2.0565
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2740  0.6665  0.4685
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.6615 -2.7080 -3.2560
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.8910 -0.2990 -1.7375
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.0735 -0.2225 -0.0810
# zonadhesin                                          0.3600  0.2525  0.3925
# zyg-11 homolog A (C. elegans)                       0.6095  0.0635  0.6660
# zygote arrest 1                                    -0.1110 -0.0745  0.4875
# zyxin                                              -0.4270 -0.3235 -0.6515
#
# strain                                               BXD19  ...   BXD69  \
# GENE_NAME                                                   ...
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.5565  ...  1.2765
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  2.3185  ...  1.9495
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3900  ...  0.4090
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -3.1915  ... -2.9405
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.6430  ... -1.6545
# ...                                                    ...  ...     ...
# zona pellucida like domain containing 1            -0.1225  ...  0.0140
# zonadhesin                                          0.2340  ...  0.0630
# zyg-11 homolog A (C. elegans)                       0.4840  ...  0.5350
# zygote arrest 1                                    -0.0955  ... -0.0925
# zyxin                                              -0.4150  ... -0.5060
#
# strain                                               BXD73   BXD77    BXD8  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  0.7425  1.4360  1.7245
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.4490  1.8260  2.0670
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2680  0.4305  0.6770
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.8110 -3.0055 -2.9290
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.7400 -0.6750 -0.4900
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1100 -0.3550  0.0940
# zonadhesin                                          0.3440  0.0840  0.2090
# zyg-11 homolog A (C. elegans)                       0.2815  0.7390  0.6840
# zygote arrest 1                                     0.3760  0.3775  0.2995
# zyxin                                              -0.3360 -0.3805 -0.6185
#
# strain                                               BXD85   BXD86    BXD9  \
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.3890  1.4395  1.1540
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.7725  1.8180  1.2430
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.3760  0.4680  0.5405
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -3.1155 -2.9195 -2.7315
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -1.8610 -0.6505 -0.5690
# ...                                                    ...     ...     ...
# zona pellucida like domain containing 1            -0.1725 -0.3360  0.0930
# zonadhesin                                          0.2685  0.1960  0.7185
# zyg-11 homolog A (C. elegans)                       0.3355  0.6170  0.5690
# zygote arrest 1                                    -0.2295  0.5980 -0.1330
# zyxin                                              -0.4655 -0.1315 -0.5515
#
# strain                                               BXD92  C57BL6J   DBA2J
# GENE_NAME
# 1-acylglycerol-3-phosphate O-acyltransferase 1 ...  1.3800  1.12200  1.3166
# 1-acylglycerol-3-phosphate O-acyltransferase 2 ...  1.7840  1.75100  1.8952
# 1-acylglycerol-3-phosphate O-acyltransferase 3      0.2110  0.53600  0.6947
# 1-acylglycerol-3-phosphate O-acyltransferase 4 ... -2.9565 -2.92500 -2.6595
# 1-acylglycerol-3-phosphate O-acyltransferase 5 ... -0.6770 -0.61000 -1.3286
# ...                                                    ...      ...     ...
# zona pellucida like domain containing 1            -0.1780 -0.03725 -0.0173
# zonadhesin                                          0.0780  0.40250  0.3905
# zyg-11 homolog A (C. elegans)                       0.6635  0.44575  0.2731
# zygote arrest 1                                    -0.1920 -0.19500  0.1497
# zyxin                                              -0.3000 -0.45625 -0.4278
#
# [17917 rows x 44 columns]

# %%
# Filter the relevant strains to include only those present in liver_df
filtered_strains_liver = [col for col in relevant_strains if col in liver_df.columns]
# Select the filtered columns from liver_df
liver_df = liver_df.loc[:, filtered_strains_liver]
# Get only the strains present in liver_df from the genotype alphabet
# Filter the genotype alphabet to include only the relevant strains
representative_snps_liver = genotype_df[filtered_strains_liver]
# Now look for snps that have exactly same values for all the strains
duplicates = representative_snps_liver[representative_snps_liver.duplicated()]
print(f"The number of duplicate SNPs is: {len(duplicates)}")
# Remove the duplicate SNPs
representative_snps_liver = representative_snps_liver.drop_duplicates()
# Out:
# The number of duplicate SNPs is: 2424

# %%
# Filtering for liver alphabet
liver_df_filtered = liver_df.dropna()
row_variance = liver_df_filtered.var(axis=1)
average_variance = row_variance.mean()
print(f"The average variance is: {round(average_variance, 3)}")
liver_df_filtered = liver_df[row_variance > average_variance/10]
row_max = liver_df_filtered.max(axis=1)
average_max = row_max.mean()
print(f"The average maximum expression value is: {round(average_max, 3)}")
liver_df_filtered = liver_df_filtered[row_max > average_max-2]
print(f"The number of genes before filtering is: {len(liver_df)} \nThe number of genes after filtering is: {len(liver_df_filtered)}")
liver_df_filtered
# Out:
# The average variance is: 0.055
# The average maximum expression value is: 0.275
# The number of duplicate SNPs is: 2424

# %%
# Function for the analysis 
def association_test(df, snps):
    eQTLs = []
    for gene in df.index:
        # Run the regression
        results = f_regression(snps.T, df.loc[gene].T)
        # Get the p-values
        p_values = results[1]
        eQTLs.append({"gene": gene, "p_values": p_values})
    eQTLs_df = pd.DataFrame(eQTLs)
    return eQTLs_df

def correct_results(df1, df2):
    # Merge the p-values columns for analysis
    p_merged = pd.concat([df1['p_values'], df2['p_values']], axis=0)
    # Correct the p-values
    p_values = list(chain.from_iterable(p_merged))
    corrected_p_values = fdrcorrection(p_values)[1]
    # Initialize new columns
    df1["corrected_p_values"] = [None] * len(df1)
    df1["significant_snps"] = [None] * len(df1)
    df2["corrected_p_values"] = [None] * len(df2)
    df2["significant_snps"] = [None] * len(df2)
    for df in [df1, df2]:
        n_snps = len(df.loc[0, "p_values"])
        for i in range(len(df)):
            start = i * n_snps
            end = (i + 1) * n_snps
            # Assign corrected p-values for each gene
            df.at[i, "corrected_p_values"] = corrected_p_values[start:end]
            # Identify significant SNPs for each gene
            df.at[i, "significant_snps"] = {genotype_df.loc[i, 'Locus']: j for i, j in enumerate(corrected_p_values[start:end]) if j < 0.05}
    # drop the genes with no significant SNPs
    eQTLs_df1= df1[df1["significant_snps"].map(lambda d: len(d)) > 0].reset_index(drop=True)
    eQTLs_df2 = df2[df2["significant_snps"].map(lambda d: len(d)) > 0].reset_index(drop=True)
    return eQTLs_df1, eQTLs_df2

def eqtl_analysis(df1, df2, snps1, snps2):
    eQTLs1 = association_test(df1, snps1)
    eQTLs2 = association_test(df2, snps2)
    eQTLs_corrected1, eQTLs_corrected2 = correct_results(eQTLs1, eQTLs2)
    return eQTLs_corrected1, eQTLs_corrected2

# %%
# Run the eQTL analysis
eQTLs_myeloid, eQTLs_liver = eqtl_analysis(myeloid_df_filtered, liver_df_filtered, representative_snps_myeloid, representative_snps_liver)
eQTLs_myeloid.head()
# Out:
#             gene                                           p_values  \
# 0  0610009K11Rik  [0.7873410843132229, 0.7873410843132229, 0.787...
# 1  0710001D07Rik  [0.5113191855604085, 0.5113191855604085, 0.511...
# 2  1110001E17Rik  [0.42799892033109144, 0.42799892033109144, 0.4...
# 3  1110003E01Rik  [0.9394831525677712, 0.9394831525677712, 0.939...
# 4  1110005F07Rik  [0.8871530382716325, 0.8871530382716325, 0.887...
#
#                                   corrected_p_values  \
# 0  [0.9986926025347768, 0.9986926025347768, 0.998...
# 1  [0.9965966668568766, 0.9965966668568766, 0.996...
# 2  [0.9957370957867651, 0.9957370957867651, 0.995...
# 3  [0.9996599129712701, 0.9996599129712701, 0.999...
# 4  [0.9992968818911117, 0.9992968818911117, 0.999...
#
#                                     significant_snps
# 0  {'rs13478002': 0.01344690210426767, 'rs4224864...
# 1  {'rs13482934': 0.00026800301316723505, 'rs3693...
# 2  {'rs13460430': 0.03851564429008389, 'rs3685305...
# 3  {'rs3657916': 0.0122725734536789, 'rs13478293'...
# 4  {'rs13478002': 0.002240700027782331, 'rs422486...

# %%
eQTLs_liver.head()
# Out:
#                                          gene  \
# 0            A kinase (PRKA) anchor protein 3
# 1               ArfGAP with dual PH domains 2
# 2    C-type lectin domain family 2, member h"
# 3    C-type lectin domain family 2, member i"
# 4  CCR4-NOT transcription complex, subunit 7"
#
#                                             p_values  \
# 0  [0.6830489507099937, 0.6850456551690991, 0.960...
# 1  [0.6069728753745729, 0.7059930847210809, 0.682...
# 2  [0.8348079984933076, 0.9576996905427395, 0.715...
# 3  [0.06144517396454861, 0.06813147768347926, 0.1...
# 4  [0.7959902314177908, 0.6422387765379605, 0.761...
#
#                                   corrected_p_values  \
# 0  [0.9989869813942279, 0.9989869813942279, 0.998...
# 1  [0.9958406034730389, 0.9958406034730389, 0.995...
# 2  [0.999985044995347, 0.999985044995347, 0.99998...
# 3  [0.03851564429008389, 0.03851564429008389, 0.7...
# 4  [0.9983927069876475, 0.9983927069876475, 0.994...
#
#                                     significant_snps
# 0  {'rs6290401': 0.01344690210426767, 'rs13477462...
# 1  {'rs13475988': 0.00026800301316723505, 'rs1347...
# 2  {'rs6218880': 0.03851564429008389, 'rs13478667...
# 3  {'rs6269442': 0.03851564429008389, 'rs6365999'...
# 4  {'rs3660779': 0.0122725734536789, 'rs13476533'...

# %%
eQTLs_counter = Counter()
for eqtl in pd.concat([eQTLs_myeloid['significant_snps'], eQTLs_liver['significant_snps']], axis=0):
    eQTLs_counter.update(eqtl.keys())
eqtls_number = len(eQTLs_counter)
print(f"There are {eqtls_number} eQTLs")
# Out:
# There are 1068 eQTLs

# %%
eQTLs_counter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 eQTLs_counter
#
# NameError: name 'eQTLs_counter' is not defined
